# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

print("Libraries Loaded Successfully!")
# Out:
# Libraries Loaded Successfully!

# %%
DATASET_PATH = "/content/drive/MyDrive/AI_Crime_Prediction/datasets/Bengaluru_Spatial.csv"

df = pd.read_csv(DATASET_PATH)

print(df.shape)

df.head()
# Out:
# /tmp/ipykernel_10438/2740897807.py:3: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(DATASET_PATH)
# (147769, 41)
#     District_Name             UnitName  FIR_YEAR  FIR_MONTH  Offence_Duration  \
# 0  Bengaluru City      Byadarahalli PS      2016         10                 0
# 1  Bengaluru City  Chickpet Traffic PS      2017          2                 0
# 2  Bengaluru City      Puttenahalli PS      2018          6                 0
# 3  Bengaluru City   South CEN Crime PS      2020          8                 0
# 4  Bengaluru City  Byatarayanapura  PS      2021         12                22
#
#    FIR_Day     FIR Type      FIR_Stage Complaint_Mode  \
# 0       27  Non Heinous  Pending Trial        Written
# 1        7  Non Heinous      Convicted        Written
# 2        6      Heinous  Pending Trial        Written
# 3       24  Non Heinous     Compounded        Written
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147769 entries, 0 to 147768
# Data columns (total 41 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   District_Name                147769 non-null  object
#  1   UnitName                     147769 non-null  object
#  2   FIR_YEAR                     147769 non-null  int64
#  3   FIR_MONTH                    147769 non-null  int64
#  4   Offence_Duration             147769 non-null  int64
#  5   FIR_Day                      147769 non-null  int64
#  6   FIR Type                     147769 non-null  object
#  7   FIR_Stage                    147769 non-null  object
#  8   Complaint_Mode               147769 non-null  object
#  9   CrimeGroup_Name              147769 non-null  object
#  10  CrimeHead_Name               147769 non-null  object
#  11  Latitude                     147769 non-null  float64
# ...

# %%
print("Total Records :", len(df))
print("Unique Grid Cells :", df["Grid_ID"].nunique())
print("Date Range :")
print(df["Date"].min())
print(df["Date"].max())
# Out:
# Total Records : 147769
# Unique Grid Cells : 2825
# Date Range :
# 2016-01-01
# 2023-12-31

# %%
OUTPUT_PATH = "/content/drive/MyDrive/AI_Crime_Prediction/datasets/AI_Dataset.csv"

df.to_csv(OUTPUT_PATH, index=False)

print("AI Dataset Saved Successfully!")
# Out:
# AI Dataset Saved Successfully!
